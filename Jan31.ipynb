# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
data=pd.read_csv(r"/home/rohan/Desktop/Python_Files_ubuntu/CZ1016/house-prices-advanced-regression-techniques/train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
data['PoolArea'].dtype
# Out:
# dtype('int64')

# %%
numericData=data[data.columns[data.dtypes == np.int64]]
# or: data.loc[:, data.dtypes == np.int64] # means you want to treat it as a2D matrix. : is everything, 1:5 means row1 to row 5 and so on
# or : data.select_dtypes(include=np.int64)
numericData.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF    ...      WoodDeckSF  OpenPorchSF  \
# 0         706           0        150    ...               0           61
# 1         978           0        284    ...             298            0
# 2         486           0        434    ...               0           42
# 3         216           0        540    ...               0           35
# 4         655           0        490    ...             192           84
#
# ...

# %%
numericData=numericData.drop(['Id','MSSubClass','OverallQual','OverallCond'], axis=1)
numericData.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0     8450       2003          2003         706           0        150
# 1     9600       1976          1976         978           0        284
# 2    11250       2001          2002         486           0        434
# 3     9550       1915          1970         216           0        540
# 4    14260       2000          2000         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF    ...      WoodDeckSF  \
# 0          856       856       854             0    ...               0
# 1         1262      1262         0             0    ...             298
# 2          920       920       866             0    ...               0
# 3          756       961       756             0    ...               0
# 4         1145      1145      1053             0    ...             192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
salePrice=pd.DataFrame(numericData.SalePrice)
salePrice.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
f, axes = plt.subplots(1,1, figsize=(24, 12))
sb.boxplot(salePrice)

# %%
f, axes = plt.subplots(1,1, figsize=(24, 12))
sb.violinplot(salePrice)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
f, axes = plt.subplots(1,1, figsize=(24, 12))
sb.distplot(salePrice)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
salePrice.skew()
# Out:
# SalePrice    1.882876
# dtype: float64
